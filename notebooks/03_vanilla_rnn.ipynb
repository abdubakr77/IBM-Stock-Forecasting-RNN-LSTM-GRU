# %% [markdown]
# # Vanilla RNN Model Training

# %%
# path setup so we can import from src
import os
import sys
sys.path.append(os.path.abspath('..'))

from src.utils import load_model_data
from src.model_rnn import build_rnn,build_attention_with_rnn
from src.train import train_model

# %% [markdown]
# ## Config
# All the hyperparameters for this model in one place, tuned separately for each architecture.

# %%
num_features = 8
timesteps = 90
lr, weight_decay = 1e-3 , 1e-3
patience = 10
dropout = 0.05

batch_size = 256
epochs = 100

target_index = 3

data_processed_dir = '../data/processed'
save_model_dir = '../models'

# %% [markdown]
# ## Load the preprocessed data
# Same train/valid/test splits saved from the preprocessing notebook, already scaled and windowed into sequences.

# %%
X_train, y_train, X_valid, y_valid, X_test, y_test = load_model_data(os.path.join(data_processed_dir,'all_model_data.pkl'))
# Out:
# Scaler & All data successfully loaded and ready for the model!

# %% [markdown]
# ## Build the Vanilla RNN model

# %%
rnn_model, rnn_callbacks = build_rnn(timesteps,num_features,
                             dropout=dropout,
                             lr=lr,
                             weight_decay=weight_decay,
                             patience=patience)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Python313\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rnn (RNN)                       │ (None, 90, 64)         │         4,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn_1 (RNN)                     │ (None, 32)             │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,809 (30.50 KB)
#  Trainable params: 7,809 (30.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Train the model
# Saves the trained model and returns its training history for later comparison.

# %%
rnn_model, rnn_history = train_model(rnn_model,
                                    [X_train, y_train],
                                    [X_valid, y_valid],
                                    epochs=epochs,
                                    batch_size=batch_size,
                                    callbacks=rnn_callbacks, 
                                    model_name='RNN',
                                    save_dir=save_model_dir
                                    )
# Out:
# RNN Is Training...
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0302 - mse: 0.0302 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0238 - mse: 0.0238 - val_loss: 0.0206 - val_mse: 0.0206
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 9.8035e-04 - mse: 9.8035e-04 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.3331e-04 - mse: 9.3331e-04 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 9.1775e-04 - mse: 9.1775e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 9.8887e-04 - mse: 9.8887e-04 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.7518e-04 - mse: 9.7518e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 9.7752e-04 - mse: 9.7752e-04 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 34/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 35/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 36/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.2370e-04 - mse: 9.2370e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 37/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 38/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 39/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 9.7439e-04 - val_mse: 9.7439e-04
# Epoch 40/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 41/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 7.6230e-04 - val_mse: 7.6230e-04
# Epoch 42/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.2013e-04 - mse: 8.2013e-04 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 43/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 44/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 7.8135e-04 - mse: 7.8135e-04 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 45/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 46/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 8.2405e-04 - mse: 8.2405e-04 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 47/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 48/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.4039e-04 - mse: 8.4039e-04 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 49/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 9.1602e-04 - mse: 9.1602e-04 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 50/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 51/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 9.4978e-04 - mse: 9.4978e-04 - val_loss: 0.0020 - val_mse: 0.0020
#
# RNN Saved Successfully!

# %%
lr, weight_decay = 1e-3 , 1e-3
patience = 10
dropout = 0

batch_size = 1024
epochs = 100

# %%
att_rnn_model, att_rnn_callbacks = build_attention_with_rnn(
                                            timesteps,
                                            num_features,
                                            dropout=dropout,
                                            lr=lr,
                                            weight_decay=weight_decay,
                                            patience=patience)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 90, 8)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rnn_2 (RNN)         │ (None, 90, 128)   │     17,536 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 90, 128)   │          0 │ rnn_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_1         │ (None, 90, 128)   │          0 │ dropout_2[0][0],  │
# │ (Attention)         │                   │            │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rnn_3 (RNN)         │ (None, 32)        │      5,152 │ attention_1[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 32)        │          0 │ rnn_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │         33 │ dropout_3[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 22,721 (88.75 KB)
#  Trainable params: 22,721 (88.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
att_rnn_model, att_rnn_history = train_model(att_rnn_model,
                                        [X_train, y_train],
                                        [X_valid, y_valid],
                                        epochs=epochs,
                                        batch_size=batch_size,
                                        callbacks=att_rnn_callbacks,
                                        model_name='Attention_RNN',
                                        save_dir=save_model_dir
                                        )
# Out:
# Attention_RNN Is Training...
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 377ms/step - loss: 0.2278 - mse: 0.2278 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 355ms/step - loss: 0.0439 - mse: 0.0439 - val_loss: 0.0583 - val_mse: 0.0583
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 344ms/step - loss: 0.0434 - mse: 0.0434 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 338ms/step - loss: 0.0095 - mse: 0.0095 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 346ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0128 - val_mse: 0.0128
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 339ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0062 - val_mse: 0.0062
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 344ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 339ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 346ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 341ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 344ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0115 - val_mse: 0.0115
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 340ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 340ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 340ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 337ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 342ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 343ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 352ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 343ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0051 - val_mse: 0.0051
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 339ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 352ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 341ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 336ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 350ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 353ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 351ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0049 - val_mse: 0.0049
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 352ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 346ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0054 - val_mse: 0.0054
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 356ms/step - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 349ms/step - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 334ms/step - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0053 - val_mse: 0.0053
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 334ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 341ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 341ms/step - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0102 - val_mse: 0.0102
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 340ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 337ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0072 - val_mse: 0.0072
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 333ms/step - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 335ms/step - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 337ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 334ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 335ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 335ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 338ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0036 - val_mse: 0.0036
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 334ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 337ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 337ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 333ms/step - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 334ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 341ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 344ms/step - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 338ms/step - loss: 9.9680e-04 - mse: 9.9680e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 333ms/step - loss: 9.9072e-04 - mse: 9.9072e-04 - val_loss: 0.0034 - val_mse: 0.0034
# Epoch 52: early stopping
# Restoring model weights from the end of the best epoch: 42.
#
# Attention_RNN Saved Successfully!
