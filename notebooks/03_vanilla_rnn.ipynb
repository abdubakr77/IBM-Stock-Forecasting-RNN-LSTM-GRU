# %%
# path setup so we can import from src
import os
import sys
sys.path.append(os.path.abspath('..'))

from src.utils import load_model_data
from src.model_rnn import build_rnn
from src.train import train_model

# %%
num_features = 8
timesteps = 90
lr, weight_decay = 5e-4 , 5e-4
patience = 10
dropout = 0

batch_size = 256
epochs = 100

target_index = 3

data_processed_dir = '../data/processed'
save_model_dir = '../models'
# Out:
# Scaler & All data successfully loaded and ready for the model!

# %%
X_train, y_train, X_valid, y_valid, X_test, y_test = load_model_data(os.path.join(data_processed_dir,'all_model_data.pkl'))

# %%
model, callbacks = build_rnn(timesteps,num_features,
                             dropout=dropout,
                             lr=lr,
                             weight_decay=weight_decay,
                             patience=patience)

# %%
model, history = train_model(model,
                             [X_train, y_train],
                             [X_valid, y_valid],
                             epochs=epochs,
                             batch_size=batch_size,
                             callbacks=callbacks, 
                             save_dir=save_model_dir
                             )
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Python313\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rnn (RNN)                       │ (None, 90, 64)         │         4,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rnn_1 (RNN)                     │ (None, 16)             │         1,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,985 (23.38 KB)
#  Trainable params: 5,985 (23.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0321 - mse: 0.0321 - val_loss: 0.0455 - val_mse: 0.0455
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0137 - mse: 0.0137 - val_loss: 0.0231 - val_mse: 0.0231
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0148 - mse: 0.0148 - val_loss: 0.0140 - val_mse: 0.0140
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0164 - mse: 0.0164 - val_loss: 0.0107 - val_mse: 0.0107
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0131 - val_mse: 0.0131
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0070 - val_mse: 0.0070
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0056 - val_mse: 0.0056
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0017 - val_mse: 0.0017
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 8.8094e-04 - mse: 8.8094e-04 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.0545e-04 - mse: 7.0545e-04 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.8035e-04 - mse: 5.8035e-04 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.0941e-04 - mse: 5.0941e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.9210e-04 - mse: 4.9210e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.5518e-04 - mse: 4.5518e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.6593e-04 - mse: 4.6593e-04 - val_loss: 9.0728e-04 - val_mse: 9.0728e-04
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.2527e-04 - mse: 4.2527e-04 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.7001e-04 - mse: 3.7001e-04 - val_loss: 8.4391e-04 - val_mse: 8.4391e-04
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.7771e-04 - mse: 3.7771e-04 - val_loss: 8.6760e-04 - val_mse: 8.6760e-04
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.6408e-04 - mse: 4.6408e-04 - val_loss: 7.6154e-04 - val_mse: 7.6154e-04
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.1582e-04 - mse: 4.1582e-04 - val_loss: 5.7971e-04 - val_mse: 5.7971e-04
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.1317e-04 - mse: 4.1317e-04 - val_loss: 4.8415e-04 - val_mse: 4.8415e-04
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.8670e-04 - mse: 3.8670e-04 - val_loss: 5.1292e-04 - val_mse: 5.1292e-04
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.6513e-04 - mse: 3.6513e-04 - val_loss: 5.3411e-04 - val_mse: 5.3411e-04
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.3795e-04 - mse: 4.3795e-04 - val_loss: 7.9789e-04 - val_mse: 7.9789e-04
# Epoch 34/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.1827e-04 - mse: 5.1827e-04 - val_loss: 0.0011 - val_mse: 0.0011
# Epoch 35/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.4230e-04 - mse: 7.4230e-04 - val_loss: 0.0015 - val_mse: 0.0015
# Epoch 36/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 37/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 38/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0014 - val_mse: 0.0014
# Epoch 39/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 40/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 8.3768e-04 - val_mse: 8.3768e-04
